# %% [markdown]
# # Matemática para Ciencia de los Datos
# # Trabajo Práctico 6
#
# Profesor: Juan Luis Crespo Mariño (basado en trabajo previo de Luis Alexánder Calvo Valverde)
#
# Instituto Tecnológico de Costa Rica,
#
# Programa Ciencia de Datos
#
# ---
#
# Fecha de entrega: 2 de septiembre, hora límite las 6:00 pm.
#
# Medio de entrega: Por medio del TEC-Digital.
#
# Entregables: Un archivo jupyter ( .IPYNB ).
#
# Estudiante:
# 1. **Roberto Baltodano**

# %% [markdown]
# ## Ejercicio 1 (50 puntos)
#
#
#
# El algoritmo del descenso de gradiente sigue la idea de modificar el punto óptimo estimado de forma iterativa. Para una función en una
# variable $f\left(x\right)$, la estimación del punto óptimo en una iteración $i+1$ está dada por:
#
# \begin{equation}
# x\left(t+1\right)=x\left(t\right)+\alpha f'\left(x\left(t\right)\right)
# \end{equation}
#
# donde el coeficiente $\alpha$ determina el *grado de confianza o velocidad* con la que el proceso de optimización iterativa sigue
# la dirección de la derivada. Para la optimización de una función multivariable $f\left(\overrightarrow{x}\left(t\right)\right)$ con $\overrightarrow{x}\in\mathbb{R}^{n}$, la posición óptima se estima usando el vector gradiente:
#
# \begin{equation}
# \overrightarrow{x}\left(t+1\right)=\overrightarrow{x}\left(t\right)+\alpha\nabla_{\overrightarrow{x}}f\left(\overrightarrow{x}\left(t\right)\right)
# \end{equation}
#
# Para la función:
#
# \begin{equation}
# f\left(\overrightarrow{x}\right)=x^{2}-y^{2},
# \end{equation}
#
# Implemente la función en python denominada:
#
# $$funcion\_SGD \left(tasa\_aprendizaje, iteraciones, xy, tolerancia\right)$$
#
# donde los parámetros corresponden a:
#
# * tasa_aprendizaje: es el $\alpha$
# * iteraciones: es el máximo número de iteraciones a ejecutar
# * xy: es el vector con los dos valores iniciales [x,y]
# * tolerancia: es el valor mínimo para un cambio entre iteración. Si la función de costo no mejora en al menos "tolerancia", sale del ciclo de iteración.
#
# **Nota:**
# 1. Para iniciar la implementación puede utilizar el código en el cuaderno "070_1_LACV_Optimizacion".
# 1. Cada iteración le generará un vector con dos valores ($\overrightarrow{x}\left(t+1\right)$), por lo que para saber el valor de la función de pérdida en ese punto, evalúelo en la función inicial ($x^{2}-y^{2}$) para saber si aumentó o disminuyó.
#
#
#
# ---

# %%
import numpy as np
# Ejercicio descenso de gradiente
# f( x, y ) =  x**2 - y**2
# código base: https://towardsdatascience.com/implement-gradient-descent-in-python-9b93ed7108d1

def gradiente_f(x, y):
    return np.array([2*x, -2*y])

def SGD(tasa_aprendizaje, iteraciones, xy, tolerancia) -> None:
    cur_xy = np.array(xy, dtype=float)
    previous_step_size = 1
    iters = 0 #iteration counter

    while previous_step_size > tolerancia and iters < iteraciones:
        prev_xy = cur_xy # Store current point value in previous_point
        cur_xy = prev_xy - tasa_aprendizaje * gradiente_f(prev_xy[0], prev_xy[1]) #Grad descent
        previous_step_size = np.linalg.norm(cur_xy - prev_xy, ord=2) # Euclidean distance
        iters += 1 #iteration count
        if (iters % 1) == 0:
            print("Iteration",iters,"\nPoint value is", cur_xy) #Print iterations
            print("previous_step_size >>> ", previous_step_size)


    print("The local minimum occurs at", cur_xy)

SGD(tasa_aprendizaje=0.1, iteraciones=1000, xy=(5, -3), tolerancia=0.000000000000000000000000001)
# Out:
# Iteration 1
# Point value is [ 4.  -2.4]
# previous_step_size >>>  1.1661903789690602
# Iteration 2
# Point value is [ 3.2  -1.92]
# previous_step_size >>>  0.9329523031752479
# Iteration 3
# Point value is [ 2.56  -1.536]
# previous_step_size >>>  0.7463618425401986
# Iteration 4
# Point value is [ 2.048  -1.2288]
# previous_step_size >>>  0.5970894740321587
# Iteration 5
# Point value is [ 1.6384  -0.98304]
# previous_step_size >>>  0.47767157922572695
# Iteration 6
# Point value is [ 1.31072  -0.786432]
# previous_step_size >>>  0.3821372633805816
# Iteration 7
# Point value is [ 1.048576  -0.6291456]
# previous_step_size >>>  0.3057098107044653
# Iteration 8
# Point value is [ 0.8388608  -0.50331648]
# previous_step_size >>>  0.24456784856357222
# Iteration 9
# Point value is [ 0.67108864 -0.40265318]
# previous_step_size >>>  0.19565427885085784
# Iteration 10
# Point value is [ 0.53687091 -0.32212255]
# previous_step_size >>>  0.1565234230806862
# Iteration 11
# Point value is [ 0.42949673 -0.25769804]
# previous_step_size >>>  0.125218738464549
# Iteration 12
# Point value is [ 0.34359738 -0.20615843]
# previous_step_size >>>  0.10017499077163922
# Iteration 13
# Point value is [ 0.27487791 -0.16492674]
# previous_step_size >>>  0.08013999261731139
# Iteration 14
# Point value is [ 0.21990233 -0.1319414 ]
# previous_step_size >>>  0.0641119940938491
# Iteration 15
# Point value is [ 0.17592186 -0.10555312]
# previous_step_size >>>  0.05128959527507927
# Iteration 16
# Point value is [ 0.14073749 -0.08444249]
# previous_step_size >>>  0.04103167622006343
# Iteration 17
# Point value is [ 0.11258999 -0.06755399]
# previous_step_size >>>  0.03282534097605073
# Iteration 18
# Point value is [ 0.09007199 -0.0540432 ]
# previous_step_size >>>  0.026260272780840588
# Iteration 19
# Point value is [ 0.07205759 -0.04323456]
# previous_step_size >>>  0.02100821822467247
# Iteration 20
# Point value is [ 0.05764608 -0.03458765]
# previous_step_size >>>  0.016806574579737974
# Iteration 21
# Point value is [ 0.04611686 -0.02767012]
# previous_step_size >>>  0.01344525966379038
# Iteration 22
# Point value is [ 0.03689349 -0.02213609]
# previous_step_size >>>  0.010756207731032303
# Iteration 23
# Point value is [ 0.02951479 -0.01770887]
# previous_step_size >>>  0.008604966184825844
# Iteration 24
# Point value is [ 0.02361183 -0.0141671 ]
# previous_step_size >>>  0.006883972947860673
# Iteration 25
# Point value is [ 0.01888947 -0.01133368]
# previous_step_size >>>  0.00550717835828854
# Iteration 26
# Point value is [ 0.01511157 -0.00906694]
# previous_step_size >>>  0.004405742686630831
# Iteration 27
# Point value is [ 0.01208926 -0.00725355]
# previous_step_size >>>  0.003524594149304665
# Iteration 28
# Point value is [ 0.00967141 -0.00580284]
# previous_step_size >>>  0.002819675319443732
# Iteration 29
# Point value is [ 0.00773713 -0.00464228]
# previous_step_size >>>  0.0022557402555549865
# Iteration 30
# Point value is [ 0.0061897  -0.00371382]
# previous_step_size >>>  0.0018045922044439887
# Iteration 31
# Point value is [ 0.00495176 -0.00297106]
# previous_step_size >>>  0.0014436737635551908
# Iteration 32
# Point value is [ 0.00396141 -0.00237684]
# previous_step_size >>>  0.0011549390108441528
# Iteration 33
# Point value is [ 0.00316913 -0.00190148]
# previous_step_size >>>  0.0009239512086753223
# Iteration 34
# Point value is [ 0.0025353  -0.00152118]
# previous_step_size >>>  0.0007391609669402578
# Iteration 35
# Point value is [ 0.00202824 -0.00121694]
# previous_step_size >>>  0.0005913287735522065
# Iteration 36
# Point value is [ 0.00162259 -0.00097356]
# previous_step_size >>>  0.00047306301884176503
# Iteration 37
# Point value is [ 0.00129807 -0.00077884]
# previous_step_size >>>  0.00037845041507341207
# Iteration 38
# Point value is [ 0.00103846 -0.00062308]
# previous_step_size >>>  0.00030276033205872964
# Iteration 39
# Point value is [ 0.00083077 -0.00049846]
# previous_step_size >>>  0.00024220826564698376
# Iteration 40
# Point value is [ 0.00066461 -0.00039877]
# previous_step_size >>>  0.00019376661251758705
# Iteration 41
# Point value is [ 0.00053169 -0.00031901]
# previous_step_size >>>  0.00015501329001406963
# Iteration 42
# Point value is [ 0.00042535 -0.00025521]
# previous_step_size >>>  0.00012401063201125564
# Iteration 43
# Point value is [ 0.00034028 -0.00020417]
# previous_step_size >>>  9.920850560900454e-05
# Iteration 44
# Point value is [ 0.00027223 -0.00016334]
# previous_step_size >>>  7.936680448720365e-05
# Iteration 45
# Point value is [ 0.00021778 -0.00013067]
# previous_step_size >>>  6.349344358976289e-05
# Iteration 46
# Point value is [ 0.00017422 -0.00010453]
# previous_step_size >>>  5.0794754871810326e-05
# Iteration 47
# Point value is [ 1.39379657e-04 -8.36277945e-05]
# previous_step_size >>>  4.063580389744827e-05
# Iteration 48
# Point value is [ 1.11503726e-04 -6.69022356e-05]
# previous_step_size >>>  3.25086431179586e-05
# Iteration 49
# Point value is [ 8.92029808e-05 -5.35217885e-05]
# previous_step_size >>>  2.6006914494366875e-05
# Iteration 50
# Point value is [ 7.13623846e-05 -4.28174308e-05]
# previous_step_size >>>  2.0805531595493507e-05
# Iteration 51
# Point value is [ 5.70899077e-05 -3.42539446e-05]
# previous_step_size >>>  1.6644425276394804e-05
# Iteration 52
# Point value is [ 4.56719262e-05 -2.74031557e-05]
# previous_step_size >>>  1.3315540221115846e-05
# Iteration 53
# Point value is [ 3.65375409e-05 -2.19225246e-05]
# previous_step_size >>>  1.0652432176892674e-05
# Iteration 54
# Point value is [ 2.92300327e-05 -1.75380196e-05]
# previous_step_size >>>  8.521945741514142e-06
# Iteration 55
# Point value is [ 2.33840262e-05 -1.40304157e-05]
# previous_step_size >>>  6.817556593211314e-06
# Iteration 56
# Point value is [ 1.87072210e-05 -1.12243326e-05]
# previous_step_size >>>  5.454045274569049e-06
# Iteration 57
# Point value is [ 1.49657768e-05 -8.97946606e-06]
# previous_step_size >>>  4.36323621965524e-06
# Iteration 58
# Point value is [ 1.19726214e-05 -7.18357285e-06]
# previous_step_size >>>  3.4905889757241924e-06
# Iteration 59
# Point value is [ 9.57809713e-06 -5.74685828e-06]
# previous_step_size >>>  2.7924711805793536e-06
# Iteration 60
# Point value is [ 7.66247770e-06 -4.59748662e-06]
# previous_step_size >>>  2.2339769444634824e-06
# Iteration 61
# Point value is [ 6.12998216e-06 -3.67798930e-06]
# previous_step_size >>>  1.7871815555707862e-06
# Iteration 62
# Point value is [ 4.90398573e-06 -2.94239144e-06]
# previous_step_size >>>  1.4297452444566292e-06
# Iteration 63
# Point value is [ 3.92318858e-06 -2.35391315e-06]
# previous_step_size >>>  1.1437961955653039e-06
# Iteration 64
# Point value is [ 3.13855087e-06 -1.88313052e-06]
# previous_step_size >>>  9.150369564522428e-07
# Iteration 65
# Point value is [ 2.51084069e-06 -1.50650442e-06]
# previous_step_size >>>  7.320295651617941e-07
# Iteration 66
# Point value is [ 2.00867256e-06 -1.20520353e-06]
# previous_step_size >>>  5.856236521294353e-07
# Iteration 67
# Point value is [ 1.60693804e-06 -9.64162827e-07]
# previous_step_size >>>  4.6849892170354837e-07
# Iteration 68
# Point value is [ 1.28555044e-06 -7.71330261e-07]
# previous_step_size >>>  3.7479913736283867e-07
# Iteration 69
# Point value is [ 1.02844035e-06 -6.17064209e-07]
# previous_step_size >>>  2.9983930989027085e-07
# Iteration 70
# Point value is [ 8.22752279e-07 -4.93651367e-07]
# previous_step_size >>>  2.3987144791221674e-07
# Iteration 71
# Point value is [ 6.58201823e-07 -3.94921094e-07]
# previous_step_size >>>  1.918971583297734e-07
# Iteration 72
# Point value is [ 5.26561458e-07 -3.15936875e-07]
# previous_step_size >>>  1.5351772666381869e-07
# Iteration 73
# Point value is [ 4.21249167e-07 -2.52749500e-07]
# previous_step_size >>>  1.22814181331055e-07
# Iteration 74
# Point value is [ 3.36999333e-07 -2.02199600e-07]
# previous_step_size >>>  9.825134506484398e-08
# Iteration 75
# Point value is [ 2.69599467e-07 -1.61759680e-07]
# previous_step_size >>>  7.860107605187516e-08
# Iteration 76
# Point value is [ 2.15679573e-07 -1.29407744e-07]
# previous_step_size >>>  6.288086084150014e-08
# Iteration 77
# Point value is [ 1.72543659e-07 -1.03526195e-07]
# previous_step_size >>>  5.030468867320012e-08
# Iteration 78
# Point value is [ 1.38034927e-07 -8.28209562e-08]
# previous_step_size >>>  4.0243750938560104e-08
# Iteration 79
# Point value is [ 1.10427942e-07 -6.62567649e-08]
# previous_step_size >>>  3.219500075084807e-08
# Iteration 80
# Point value is [ 8.83423532e-08 -5.30054119e-08]
# previous_step_size >>>  2.5756000600678463e-08
# Iteration 81
# Point value is [ 7.06738826e-08 -4.24043296e-08]
# previous_step_size >>>  2.0604800480542762e-08
# Iteration 82
# Point value is [ 5.65391061e-08 -3.39234636e-08]
# previous_step_size >>>  1.648384038443421e-08
# Iteration 83
# Point value is [ 4.52312849e-08 -2.71387709e-08]
# previous_step_size >>>  1.3187072307547372e-08
# Iteration 84
# Point value is [ 3.61850279e-08 -2.17110167e-08]
# previous_step_size >>>  1.0549657846037897e-08
# Iteration 85
# Point value is [ 2.89480223e-08 -1.73688134e-08]
# Iteration 112
# Point value is [ 6.99920232e-11 -4.19952139e-11]
# previous_step_size >>>  2.040600601308043e-11
# Iteration 113
# Point value is [ 5.59936186e-11 -3.35961711e-11]
# previous_step_size >>>  1.632480481046435e-11
# Iteration 114
# Point value is [ 4.47948948e-11 -2.68769369e-11]
# previous_step_size >>>  1.305984384837148e-11
# Iteration 115
# Point value is [ 3.58359159e-11 -2.15015495e-11]
# previous_step_size >>>  1.0447875078697186e-11
# Iteration 116
# Point value is [ 2.86687327e-11 -1.72012396e-11]
# previous_step_size >>>  8.358300062957746e-12
# Iteration 117
# Point value is [ 2.29349862e-11 -1.37609917e-11]
# previous_step_size >>>  6.686640050366197e-12
# Iteration 118
# Point value is [ 1.83479889e-11 -1.10087934e-11]
# previous_step_size >>>  5.349312040292959e-12
# Iteration 119
# Point value is [ 1.46783911e-11 -8.80703469e-12]
# previous_step_size >>>  4.279449632234367e-12
# Iteration 120
# Point value is [ 1.17427129e-11 -7.04562775e-12]
# previous_step_size >>>  3.423559705787493e-12
# Iteration 121
# Point value is [ 9.39417033e-12 -5.63650220e-12]
# previous_step_size >>>  2.7388477646299942e-12
# Iteration 122
# Point value is [ 7.51533626e-12 -4.50920176e-12]
# previous_step_size >>>  2.1910782117039955e-12
# Iteration 123
# Point value is [ 6.01226901e-12 -3.60736141e-12]
# previous_step_size >>>  1.7528625693631962e-12
# Iteration 124
# Point value is [ 4.80981521e-12 -2.88588913e-12]
# previous_step_size >>>  1.4022900554905568e-12
# Iteration 125
# Point value is [ 3.84785217e-12 -2.30871130e-12]
# previous_step_size >>>  1.1218320443924453e-12
# Iteration 126
# Point value is [ 3.07828173e-12 -1.84696904e-12]
# previous_step_size >>>  8.974656355139568e-13
# Iteration 127
# Point value is [ 2.46262539e-12 -1.47757523e-12]
# previous_step_size >>>  7.179725084111653e-13
# Iteration 128
# Point value is [ 1.97010031e-12 -1.18206019e-12]
# previous_step_size >>>  5.743780067289323e-13
# Iteration 129
# Point value is [ 1.57608025e-12 -9.45648149e-13]
# previous_step_size >>>  4.595024053831457e-13
# Iteration 130
# Point value is [ 1.26086420e-12 -7.56518519e-13]
# previous_step_size >>>  3.6760192430651656e-13
# Iteration 131
# Point value is [ 1.00869136e-12 -6.05214815e-13]
# previous_step_size >>>  2.940815394452133e-13
# Iteration 132
# Point value is [ 8.06953087e-13 -4.84171852e-13]
# previous_step_size >>>  2.352652315561706e-13
# Iteration 133
# Point value is [ 6.45562470e-13 -3.87337482e-13]
# previous_step_size >>>  1.8821218524493646e-13
# Iteration 134
# Point value is [ 5.16449976e-13 -3.09869985e-13]
# previous_step_size >>>  1.5056974819594922e-13
# Iteration 135
# Point value is [ 4.13159980e-13 -2.47895988e-13]
# previous_step_size >>>  1.2045579855675936e-13
# Iteration 136
# Point value is [ 3.30527984e-13 -1.98316791e-13]
# previous_step_size >>>  9.636463884540748e-14
# Iteration 137
# Point value is [ 2.64422388e-13 -1.58653433e-13]
# previous_step_size >>>  7.7091711076326e-14
# Iteration 138
# Point value is [ 2.11537910e-13 -1.26922746e-13]
# previous_step_size >>>  4.506786478507654e-19
# Iteration 192
# Point value is [ 1.23665201e-18 -7.41991204e-19]
# previous_step_size >>>  3.6054291828061233e-19
# Iteration 193
# Point value is [ 9.89321606e-19 -5.93592964e-19]
# previous_step_size >>>  2.8843433462448987e-19
# Iteration 194
# Point value is [ 7.91457285e-19 -4.74874371e-19]
# previous_step_size >>>  2.3074746769959187e-19
# Iteration 195
# Point value is [ 6.33165828e-19 -3.79899497e-19]
# previous_step_size >>>  1.8459797415967352e-19
# Iteration 196
# Point value is [ 5.06532662e-19 -3.03919597e-19]
# previous_step_size >>>  1.476783793277388e-19
# Iteration 197
# Point value is [ 4.05226130e-19 -2.43135678e-19]
# previous_step_size >>>  1.1814270346219104e-19
# Iteration 198
# Point value is [ 3.24180904e-19 -1.94508542e-19]
# previous_step_size >>>  9.451416276975286e-20
# Iteration 199
# Point value is [ 2.59344723e-19 -1.55606834e-19]
# previous_step_size >>>  7.561133021580225e-20
# Iteration 200
# Point value is [ 2.07475778e-19 -1.24485467e-19]
# previous_step_size >>>  6.048906417264181e-20
# Iteration 201
# Point value is [ 1.65980623e-19 -9.95883737e-20]
# previous_step_size >>>  4.839125133811345e-20
# Iteration 202
# Point value is [ 1.32784498e-19 -7.96706989e-20]
# previous_step_size >>>  3.871300107049077e-20
# Iteration 203
# Point value is [ 1.06227599e-19 -6.37365591e-20]
# previous_step_size >>>  3.0970400856392617e-20
# Iteration 204
# Point value is [ 8.49820789e-20 -5.09892473e-20]
# previous_step_size >>>  2.4776320685114087e-20
# Iteration 205
# Point value is [ 6.79856631e-20 -4.07913978e-20]
# previous_step_size >>>  1.9821056548091266e-20
# Iteration 206
# Point value is [ 5.43885305e-20 -3.26331183e-20]
# previous_step_size >>>  1.5856845238473012e-20
# Iteration 207
# Point value is [ 4.35108244e-20 -2.61064946e-20]
# previous_step_size >>>  1.2685476190778417e-20
# Iteration 208
# Point value is [ 3.48086595e-20 -2.08851957e-20]
# previous_step_size >>>  1.014838095262273e-20
# Iteration 209
# Point value is [ 2.78469276e-20 -1.67081566e-20]
# previous_step_size >>>  8.118704762098183e-21
# Iteration 210
# Point value is [ 2.22775421e-20 -1.33665252e-20]
# previous_step_size >>>  6.4949638096785494e-21
# Iteration 211
# Point value is [ 1.78220337e-20 -1.06932202e-20]
# previous_step_size >>>  5.195971047742839e-21
# Iteration 212
# Point value is [ 1.42576269e-20 -8.55457616e-21]
# previous_step_size >>>  4.156776838194272e-21
# Iteration 213
# Point value is [ 1.14061015e-20 -6.84366093e-21]
# previous_step_size >>>  3.3254214705554162e-21
# Iteration 214
# Point value is [ 9.12488124e-21 -5.47492874e-21]
# previous_step_size >>>  2.660337176444333e-21
# Iteration 215
# Point value is [ 7.29990499e-21 -4.37994299e-21]
# previous_step_size >>>  2.1282697411554677e-21
# Iteration 216
# Point value is [ 5.83992399e-21 -3.50395439e-21]
# previous_step_size >>>  1.7026157929243736e-21
# Iteration 217
# Point value is [ 4.67193919e-21 -2.80316352e-21]
# previous_step_size >>>  1.3620926343394988e-21
# Iteration 218
# Point value is [ 3.73755135e-21 -2.24253081e-21]
# previous_step_size >>>  1.0896741074715991e-21
# Iteration 219
# Point value is [ 2.99004108e-21 -1.79402465e-21]
# previous_step_size >>>  8.71739285977279e-22
# Iteration 220
# Point value is [ 2.39203287e-21 -1.43521972e-21]
# previous_step_size >>>  6.973914287818232e-22
# Iteration 221
# Point value is [ 1.91362629e-21 -1.14817578e-21]
# previous_step_size >>>  5.579131430254585e-22
# Iteration 222
# Point value is [ 1.53090103e-21 -9.18540621e-22]
# previous_step_size >>>  4.46330514420367e-22
# Iteration 223
# Point value is [ 1.22472083e-21 -7.34832497e-22]
# previous_step_size >>>  3.5706441153629346e-22
# Iteration 224
# Point value is [ 9.79776662e-22 -5.87865997e-22]
# previous_step_size >>>  2.856515292290348e-22
# Iteration 225
# Point value is [ 7.83821330e-22 -4.70292798e-22]
# previous_step_size >>>  2.2852122338322794e-22
# Iteration 226
# Point value is [ 6.27057064e-22 -3.76234238e-22]
# previous_step_size >>>  1.8281697870658232e-22
# Iteration 227
# Point value is [ 5.01645651e-22 -3.00987391e-22]
# previous_step_size >>>  1.4625358296526586e-22
# Iteration 228
# Point value is [ 4.01316521e-22 -2.40789912e-22]
# previous_step_size >>>  1.1700286637221266e-22
# Iteration 229
# Point value is [ 3.21053217e-22 -1.92631930e-22]
# previous_step_size >>>  9.360229309777013e-23
# Iteration 230
# Point value is [ 2.56842573e-22 -1.54105544e-22]
# previous_step_size >>>  7.48818344782161e-23
# Iteration 231
# Point value is [ 2.05474059e-22 -1.23284435e-22]
# previous_step_size >>>  5.990546758257289e-23
# Iteration 232
# Point value is [ 1.64379247e-22 -9.86275482e-23]
# previous_step_size >>>  4.792437406605831e-23
# Iteration 233
# Point value is [ 1.31503398e-22 -7.89020385e-23]
# previous_step_size >>>  3.833949925284664e-23
# Iteration 234
# Point value is [ 1.05202718e-22 -6.31216308e-23]
# previous_step_size >>>  3.0671599402277326e-23
# Iteration 235
# Point value is [ 8.41621744e-23 -5.04973047e-23]
# previous_step_size >>>  2.4537279521821858e-23
# Iteration 236
# Point value is [ 6.73297395e-23 -4.03978437e-23]
# previous_step_size >>>  1.9629823617457484e-23
# Iteration 237
# Point value is [ 5.38637916e-23 -3.23182750e-23]
# previous_step_size >>>  1.5703858893965984e-23
# Iteration 238
# Point value is [ 4.30910333e-23 -2.58546200e-23]
# previous_step_size >>>  1.2563087115172793e-23
# Iteration 239
# Point value is [ 3.44728266e-23 -2.06836960e-23]
# previous_step_size >>>  1.0050469692138237e-23
# Iteration 240
# Point value is [ 2.75782613e-23 -1.65469568e-23]
# previous_step_size >>>  8.040375753710585e-24
# Iteration 241
# Point value is [ 2.20626091e-23 -1.32375654e-23]
# previous_step_size >>>  6.4323006029684696e-24
# Iteration 242
# Point value is [ 1.76500872e-23 -1.05900523e-23]
# previous_step_size >>>  5.145840482374777e-24
# Iteration 243
# Point value is [ 1.41200698e-23 -8.47204188e-24]
# previous_step_size >>>  4.11667238589982e-24
# Iteration 244
# Point value is [ 1.12960558e-23 -6.77763350e-24]
# previous_step_size >>>  3.2933379087198573e-24
# Iteration 245
# Point value is [ 9.03684467e-24 -5.42210680e-24]
# previous_step_size >>>  2.634670326975885e-24
# Iteration 246
# Point value is [ 7.22947573e-24 -4.33768544e-24]
# previous_step_size >>>  2.107736261580708e-24
# Iteration 247
# Point value is [ 5.78358059e-24 -3.47014835e-24]
# previous_step_size >>>  1.6861890092645664e-24
# Iteration 248
# Point value is [ 4.62686447e-24 -2.77611868e-24]
# previous_step_size >>>  1.3489512074116539e-24
# Iteration 249
# Point value is [ 3.70149158e-24 -2.22089495e-24]
# previous_step_size >>>  1.0791609659293228e-24
# Iteration 250
# Point value is [ 2.96119326e-24 -1.77671596e-24]
# previous_step_size >>>  8.633287727434584e-25
# Iteration 251
# Point value is [ 2.36895461e-24 -1.42137277e-24]
# previous_step_size >>>  6.906630181947665e-25
# Iteration 252
# Point value is [ 1.89516369e-24 -1.13709821e-24]
# previous_step_size >>>  5.525304145558131e-25
# Iteration 253
# Point value is [ 1.51613095e-24 -9.09678570e-25]
# previous_step_size >>>  4.420243316446505e-25
# Iteration 254
# Point value is [ 1.21290476e-24 -7.27742856e-25]
# previous_step_size >>>  3.5361946531572046e-25
# Iteration 255
# Point value is [ 9.70323808e-25 -5.82194285e-25]
# previous_step_size >>>  2.8289557225257645e-25
# Iteration 256
# Point value is [ 7.76259046e-25 -4.65755428e-25]
# previous_step_size >>>  2.263164578020611e-25
# Iteration 257
# Point value is [ 6.21007237e-25 -3.72604342e-25]
# previous_step_size >>>  1.810531662416489e-25
# Iteration 258
# Point value is [ 4.96805790e-25 -2.98083474e-25]
# previous_step_size >>>  1.4484253299331916e-25
# Iteration 259
# Point value is [ 3.97444632e-25 -2.38466779e-25]
# previous_step_size >>>  1.158740263946553e-25
# Iteration 260
# Point value is [ 3.17955705e-25 -1.90773423e-25]
# previous_step_size >>>  9.269922111572424e-26
# Iteration 261
# Point value is [ 2.54364564e-25 -1.52618739e-25]
# previous_step_size >>>  7.41593768925794e-26
# Iteration 262
# Point value is [ 2.03491651e-25 -1.22094991e-25]
# previous_step_size >>>  5.932750151406352e-26
# Iteration 263
# Point value is [ 1.62793321e-25 -9.76759927e-26]
# previous_step_size >>>  4.746200121125082e-26
# Iteration 264
# Point value is [ 1.30234657e-25 -7.81407941e-26]
# previous_step_size >>>  3.7969600969000655e-26
# Iteration 265
# Point value is [ 1.04187726e-25 -6.25126353e-26]
# previous_step_size >>>  3.0375680775200515e-26
# Iteration 266
# Point value is [ 8.33501804e-26 -5.00101082e-26]
# previous_step_size >>>  2.430054462016042e-26
# Iteration 267
# Point value is [ 6.66801443e-26 -4.00080866e-26]
# previous_step_size >>>  1.9440435696128334e-26
# Iteration 268
# Point value is [ 5.33441155e-26 -3.20064693e-26]
# previous_step_size >>>  1.5552348556902673e-26
# Iteration 269
# Point value is [ 4.26752924e-26 -2.56051754e-26]
# previous_step_size >>>  1.2441878845522134e-26
# Iteration 270
# Point value is [ 3.41402339e-26 -2.04841403e-26]
# previous_step_size >>>  9.953503076417705e-27
# Iteration 271
# Point value is [ 2.73121871e-26 -1.63873123e-26]
# previous_step_size >>>  7.962802461134165e-27
# Iteration 272
# Point value is [ 2.18497497e-26 -1.31098498e-26]
# previous_step_size >>>  6.3702419689073306e-27
# Iteration 273
# Point value is [ 1.74797998e-26 -1.04878799e-26]
# previous_step_size >>>  5.096193575125866e-27
# Iteration 274
# Point value is [ 1.39838398e-26 -8.39030388e-27]
# previous_step_size >>>  4.076954860100694e-27
# Iteration 275
# Point value is [ 1.11870718e-26 -6.71224311e-27]
# previous_step_size >>>  3.2615638880805545e-27
# Iteration 276
# Point value is [ 8.94965747e-27 -5.36979448e-27]
# previous_step_size >>>  2.6092511104644434e-27
# Iteration 277
# Point value is [ 7.15972598e-27 -4.29583559e-27]
# previous_step_size >>>  2.087400888371555e-27
# Iteration 278
# Point value is [ 5.72778078e-27 -3.43666847e-27]
# previous_step_size >>>  1.669920710697244e-27
# Iteration 279
# Point value is [ 4.58222463e-27 -2.74933478e-27]
# previous_step_size >>>  1.3359365685577948e-27
# Iteration 280
# Point value is [ 3.66577970e-27 -2.19946782e-27]
# previous_step_size >>>  1.0687492548462357e-27
# Iteration 281
# Point value is [ 2.93262376e-27 -1.75957426e-27]
# previous_step_size >>>  8.54999403876989e-28
# The local minimum occurs at [ 2.93262376e-27 -1.75957426e-27]

# %% [markdown]
# ## Ejercicio 2
#
# Para la función  $f_{1}\left(x_{1},x_{2}\right)=x_{1}^3 + x_{2}^3 - 3x_{1}^2 - 3x_{2}^2 - 3x_{1}x_{2} +2 $
#
# Realice lo siguiente:
#
# 1. En una celda de texto:
#
#  - Calcule el vector gradiente. **(15 puntos)**
#
#  - Calcule la matriz Hessiana. **(15 puntos)**
#
# 2. Para el resultado obtenido en el punto anterior: **(20 puntos)**
#   - Evalúela en los puntos que tentativamente anulen el gradiente de la misma (pueden usar python o métodos similares para resolver sistemas de ecuaciones, si lo necesitan).
#   - Luego aplique el criterio de la segunda derivada parcial ¿qué conclusiones saca para esos puntos?
#
# ---

# %% [markdown]
# $f(x,y) = x^{3} + y^{3} - 3x^{2} - 3y^{2} - 3xy + 2$
#
# ### Derivadas parciales de primer orden
#
# $\frac{\partial f(x,y)}{\partial x} = 3x^{2} - 6x - 3y$
#
# $\frac{\partial f(x,y)}{\partial y} = 3y^{2} - 6y - 3x$
#
# ### Vector gradiente
#
# $\nabla f(x,y) = \left( 3x^{2} - 6x - 3y,\; 3y^{2} - 6y - 3x \right)$
#
# ### Derivadas parciales de segundo orden
#
# $\frac{\partial^{2} f}{\partial x^{2}} = 6x - 6$
#
# $\frac{\partial^{2} f}{\partial y^{2}} = 6y - 6$
#
# $\frac{\partial^{2} f}{\partial x \partial y} =
# \frac{\partial^{2} f}{\partial y \partial x} = -3$
#
# ### Matriz Hessiana
#
# $Hf(x,y) =
# \begin{pmatrix}
# 6x - 6 & -3 \\
# -3 & 6y - 6
# \end{pmatrix}$

# %%
def grad(x, y):
    return np.array([3*x**2 + 6*x - 4*y, 4*y**3 + 8*y - 4*x - 5])

#def puntosDeAnulacion(gradiente):
# Out:
# [ 0.00113088 -0.00074252]
